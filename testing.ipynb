# %%
from transformers import AutoProcessor, AutoModelForCausalLM  
from PIL import Image
import requests
import copy
import torch
# %matplotlib inline

# %%
model_id = 'microsoft/Florence-2-large'
model = AutoModelForCausalLM.from_pretrained(model_id, trust_remote_code=True, torch_dtype='auto').eval().cuda()
processor = AutoProcessor.from_pretrained(model_id, trust_remote_code=True)

# %%
def run_example(task_prompt, text_input=None):
    if text_input is None:
        prompt = task_prompt
    else:
        prompt = task_prompt + text_input
    inputs = processor(text=prompt, images=image, return_tensors="pt").to('cuda', torch.float16)
    generated_ids = model.generate(
      input_ids=inputs["input_ids"].cuda(),
      pixel_values=inputs["pixel_values"].cuda(),
      max_new_tokens=1024,
      early_stopping=False,
      do_sample=False,
      num_beams=3,
    )
    generated_text = processor.batch_decode(generated_ids, skip_special_tokens=False)[0]
    parsed_answer = processor.post_process_generation(
        generated_text, 
        task=task_prompt, 
        image_size=(image.width, image.height)
    )

    return parsed_answer

# %%
image = Image.open('image.png').convert("RGB")

# %%
run_example('<VQA>', text_input='what Q number is this? Please answer in ONE short word and DO NOT output any <loc_*> tokens or bounding boxes. Answer:')
# Out:
# {'<VQA>': 'VQA>what Q number is this? Please answer in ONE short word and DO NOT output any <loc_*> tokens or bounding boxes. Answer:<loc_0><loc_0><loc_999><loc_999>'}

# %% [markdown]
# {'<VQA>': 'VQA>what section are we on on<loc_0><loc_0><loc_999><loc_999>'}

# %%
tasks = [    
    '<OCR>',
    '<OCR_WITH_REGION>',
    '<CAPTION>',
    '<DETAILED_CAPTION>',
    '<MORE_DETAILED_CAPTION>',
    '<OD>',
    '<DENSE_REGION_CAPTION>',
    '<CAPTION_TO_PHRASE_GROUNDING>',
    '<REFERRING_EXPRESSION_SEGMENTATION>',
    '<REGION_TO_SEGMENTATION>',
    '<OPEN_VOCABULARY_DETECTION>',
    '<REGION_TO_CATEGORY>',
    '<REGION_TO_DESCRIPTION>',
    '<REGION_TO_OCR>',
    '<REGION_PROPOSAL>',
    ]

for task in tasks:
    print(run_example(task))
# Out:
# {'<OCR>': "Digital signature Flow:\nNot writing, much since\nA\nRSA key generation: CreaSida: Not writing, such since\nD Generate P.g.ofcompute m.e.d. j.xegistex le (d) with tp(withTPE\n8) Digital signature = E (PRA(X)\nDigital signature h=SHA256(x) (X) x xis maisDitsecret)\nand convertit\n(a) Compute hayh = hd mod n = using signet's private d)\n(b) Signi: sig(sig(s)\nto inteigneHt\n(c) Transmit (x sig) = valu(s))\nVerification (c)\nVerification (x Sig(s)(x) = values) and H=int. from bytes(ch), 'big)\n1) Compule n = siga(s(x)) and using: signals public key (e(n)\n3) Recover V = sig(modn = n= H=1modn) = signals publick key (c(n))\nAccept signature if n=H-modn\nattention to be practicn\n3\nAuthenticated Handshake (SS1-H=1-Style) = seccently than aspertoably\nC)\n- sender(CA):\n. Generate diffe tellman secret S & hashit hs = SHA256(s).\nD Sign with A's private key : sig+Sigma(hs) = hs2 modn = E(PRA)\nForm anenuelofofa payload (sig+s) = sig+sigma(sis) = decimals(g)\n2) Encrypt payload with B's public key(e) = z= Encrypte (payload)\nThis corresponding to E.Pubs, E.Pra(X)) = Enrypte Payload\n. Receiver (B):\n2\nRecipientz write B's private Key to b to rec
.2724914550781, 532.8889770507812, 357.8454895019531, 43.29899978637695, 367.2065124511719], [43.29899978637695, 372.3125, 532.322998046875, 357.8454895019531, 532.8889770507812, 379.1205139160156, 43.29899978637695, 393.5874938964844], [41.03499984741211, 394.4385070800781, 519.8709716796875, 384.22650146484375, 520.43701171875, 405.5014953613281, 41.03499984741211, 414.8625183105469], [41.03499984741211, 419.11749267578125, 519.8709716796875, 418.2665100097656, 519.8709716796875, 437.8395080566406, 41.03499984741211, 439.54150390625], [41.03499984741211, 440.39251708984375, 552.698974609375, 439.54150390625, 552.698974609375, 458.2635192871094, 41.03499984741211, 459.96551513671875], [41.03499984741211, 465.0715026855469, 189.32699584960938, 465.0715026855469, 189.32699584960938, 484.6445007324219, 41.03499984741211, 484.6445007324219], [39.336997985839844, 490.60150146484375, 544.208984375, 482.09149169921875, 544.208984375, 503.36651611328125, 39.336997985839844, 511.8764953613281], [41.03499984741211, 516.9824829101562, 495.5329895019531, 505.91949462890625, 496.0989990234375, 526.343505859375, 41.03499984741211, 537.406494140625], [43.29899978637695, 538.2575073242188, 483.08099365234375, 505.91949462890625, 483.64697265625, 526.343505859375, 43.29899978637695, 559.5325317382812], [41.03499984741211, 562.0855102539062, 444.5929870605469, 556.9794921875, 445.15899658203125, 577.4035034179688, 41.03499984741211, 583.3605346679688], [43.29899978637695, 584.2114868164062, 535.718994140625, 574.8505249023438, 536.2849731445312, 596.9765014648438, 43.29899978637695, 6 ...
# {'<CAPTION>': 'A piece of paper that has some writing on it.'}
# {'<DETAILED_CAPTION>': 'The image shows a piece of paper with a bunch of writing on it, which appears to be a digital signature flow worksheet. The paper is filled with text, likely related to the worksheet, and the handwriting is neat and legible.'}
# {'<MORE_DETAILED_CAPTION>': 'The image is a list of handwritten notes on a piece of paper. The notes are written in black ink and are arranged in a neat and organized manner. The title of the notes is "Digital Signature Flow" and it appears to be a tutorial or guide on how to write a digital signature flow. \n\nThe notes are divided into two columns, with the left column containing the title "Digital signature flow" and the right column containing a description of the process. The first column is titled "RSA key generation" and contains a list that explains the process in detail. The second column has a description that explains how to use the digital signature function. The third column has an explanation of how the process works.\n\nAt the bottom of the page, there is a note that reads "Verify signature with a public key PUA". The note is written in a clear and concise manner, making it easy to read and understand.'}
# {'<OD>': {'bboxes': [[0.28299999237060547, 0.4255000054836273, 565.7169799804688, 849.7235107421875]], 'labels': ['whiteboard']}}
# {'<DENSE_REGION_CAPTION>': {'bboxes': [[0.28299999237060547, 0.4255000054836273, 565.7169799804688, 849.7235107421875]], 'labels': ['digital signature flow worksheet']}}
# {'<CAPTION_TO_PHRASE_GROUNDING>': {'bboxes': [[1.9809999465942383, 2.127500057220459, 564.5849609375, 848.021484375]], 'labels': ['']}}
603271484, 2.127500057220459, 50.65699768066406, 2.127500057220459, 51.222999572753906, 2.127500057220459, 51.788997650146484, 2.127500057220459, 52.35499954223633, 2.127500057220459, 52.920997619628906, 2.127500057220459, 53.48699951171875, 2.127500057220459, 54.05299758911133, 2.127500057220459, 54.61899948120117, 2.127500057220459, 55.18499755859375, 2.127500057220459, 55.750999450683594, 2.127500057220459, 56.31699752807617, 2.127500057220459, 56.882999420166016, 2.127500057220459, 57.448997497558594, 2.127500057220459, 58.01499938964844, 2.127500057220459, 58.580997467041016, 2.127500057220459, 59.14699935913086, 2.127500057220459, 59.71299743652344, 2.127500057220459, 60.27899932861328, 2.127500057220459, 60.84499740600586, 2.127500057220459, 61.4109992980957, 2.127500057220459, 61.97699737548828, 2.127500057220459, 62.542999267578125, 2.127500057220459, 63.1089973449707, 2.127500057220459, 63.67499923706055, 2.127500057220459, 64.24099731445312, 2.127500057220459, 64.80699920654297, 2.127500057220459, 65.37300109863281, 2.127500057220459, 65.93899536132812, 2.127500057220459, 66.50499725341797, 2.127500057220459, 67.07099914550781, 2.127500057220459, 67.63700103759766, 2.127500057220459, 68.20299530029297, 2.127500057220459, 68.76899719238281 ...
# {'<OPEN_VOCABULARY_DETECTION>': {'bboxes': [[3.11299991607666, 3.8294999599456787, 563.4530029296875, 846.3195190429688]], 'bboxes_labels': [''], 'polygons': [], 'polygons_labels': []}}
# {'<REGION_TO_CATEGORY>': 'whiteboard<loc_0><loc_0><loc_998><loc_998>'}
# {'<REGION_TO_DESCRIPTION>': 'A piece of paper with a bunch of writing on it.'}
# {'<REGION_TO_OCR>': "Digital signature Flow ::\nNot writing, much since\nA\nRSA key generation: Creasside) Not writing. Much since\nD Generate P.g.ofcompute m.e.j.d. xegistex le (e.d) with tp.usinTPE.xp\nD) Generate p.gofompute n.e,j. d.xegistex le(e.p) with TPE\n8) Digital signature = E (Pra.x)\nDigital signature h=SHA256(X) X is masDitsecret\nand convertit it\n(a) Compute hayt h= Hd mod n = using signet's private d)\n(b) Signi: sig(sig(x) = to integie H.\n(c) Transmit (Cx sig) = valu(s) values)\nVerification (Reaiver) =\n(1) Compule h= SHA56(x)) and H=int.from.byber(chi), 'big)\n3) Recover v = sig(modn(x), and using: signals public key (cen)\nRecover v= sig.modn = N=H-modn\n3 Accept signature if n= H-modin\nattention to be protetto\n3\nAuthenticated Handshake (SS1-H-Modin) =:\nAuthorized Handshake(ss1-Style) :: secently than aspertoably\n. sender(CA):\n. Generate diffe tellman secret S & hashit hs=SHA56(s).\nD Sign with A's private key : sig: sigma(hs) = hs2 mod n= E(PRAX)\nForm anenuelofofa payload (sig: siga(siga) = decimalisig)3)\n2) Encrypt payload with B's public key [sig; siga; sigma; sigm: = encimalsig3) = = Encrypte (payload)\n4) This correspond to E.Puß, E(PrA,X) = (PRA,X))\n. Receiver (B):\nReceiver (C:):\n(2) Recipientz write B's privatie key to b to recover manage S and\n(3) Signatize sig = sig(s privatice key to db to recover makage s and\n2] Signate sig = S#HAS6(S) =(D) pra2(s))\n(4) Signate sig = sigm(s] = (pra,x)) = (gipoax)\n1) Signalture sig = = siga with publickey (ca.na) = gipopoax\n2\n2 Compute h=S#HAs6(s), to D(Pra,2)\nCheck: sig. mod ma = int(hs), comepondly to (D(Pua,D(PRa,D)Pro,Z)\nB Verify signature & sig with publick key (a.na).\nCheck : sig. ma = in(ths) = [pua, D(PR,Pro,z)\nIf verification successful, detive senienkey R = KDF(S).\nSecure Message Exchange\n0 Sendex message hash hm = SHaSS(M) J Sign: sigm=h M.M.\nD Sendex Message hash Hm : SHaS(m) = Sign:siga(m), sig:h m.m)\nD Form the message payload = timi: bytes(m); sig:sig=h.m;\n(sigm:sigma(m).\n3 Encrypt payload with symmetric sexionkey (k(cg:XG:xGxR stream)\nand send the sender\nD Recrypt with K toobblair sig M.\n# DReceive\nD Verify signature wing A's publickey PUA. If valid, attept;\n+ otherwisediscord\n"}
# {'<REGION_PROPOSAL>': {'bboxes': [[0.28299999237060547, 0.4255000054836273, 565.7169799804688, 849.7235107421875]], 'labels': ['']}}

# %%
# !pip freeze > requirements.txt
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
import re
from transformers import AutoTokenizer

# cache tokenizer / bad_words_ids once
try:
    _tokenizer = processor.tokenizer
except Exception:
    _tokenizer = AutoTokenizer.from_pretrained("microsoft/Florence-2-large", trust_remote_code=True)

_bad_words_ids = [[_tokenizer.get_vocab()[tok]] for tok in _tokenizer.get_vocab() if tok.startswith("<")]

def natural_vqa(question, max_new_tokens=64, num_beams=4, block_angle_brackets=True):
    prompt = f"Question: {question} Answer:"
    # request tensors (torch.float32 by default)
    inputs = processor(text=prompt, images=image, return_tensors="pt")

    # determine model/device/dtype
    model_device = next(model.parameters()).device
    model_dtype = next(model.parameters()).dtype

    # move/cast both input_ids and pixel_values to the model device & dtype
    # input_ids should stay integer type on device; only pixel_values must be cast to model dtype
    input_ids = inputs["input_ids"].to(model_device)
    # pixel_values must be same dtype as model parameters (float16 if model is half)
    pixel_values = inputs["pixel_values"].to(device=model_device, dtype=model_dtype)

    gen_kwargs = dict(
        input_ids=input_ids,
        pixel_values=pixel_values,
        max_new_tokens=max_new_tokens,
        num_beams=num_beams,
        do_sample=False,
        early_stopping=True,
    )

    if block_angle_brackets and _bad_words_ids:
        gen_kwargs["bad_words_ids"] = _bad_words_ids

    gen = model.generate(**gen_kwargs)
    raw = processor.batch_decode(gen, skip_special_tokens=False)[0]

    # clean up angle-bracket tokens if any remain
    cleaned = re.sub(r"<[^>]+>", "", raw).strip()
    # further clean: remove leading "VQA>" or "QA>" fragments
    cleaned = re.sub(r"^(VQA>|QA>|<VQA>)\s*", "", cleaned, flags=re.IGNORECASE)
    return {"raw": raw, "clean": cleaned}

# %%
natural_vqa('this is Q. number')
# Out:
# {'raw': '</s><s>Q. number Answer (i) question: "This is Q. number answer: "this is Q." question: \'this is q. question: This is Q.\' question: this is Q \'s question:</s>',
#  'clean': 'Q. number Answer (i) question: "This is Q. number answer: "this is Q." question: \'this is q. question: This is Q.\' question: this is Q \'s question:'}
